# %%
stack = []

# push elements to stack
stack.append(10)
stack.append(20)
stack.append(30)

print(stack)
# Out:
# [10, 20, 30]

# %%
#peek
print(stack[-1])
# Out:
# 30

# %%
stack.pop() #pop
print(stack)
# Out:
# [10, 20]

# %%
print(len(stack) == 0) #empty() - check if stack is empty, returns boolean
# Out:
# False
